# %% [markdown]
# # 4fold
#
# If you wish to use GPU, change 'gpu' and 'use_gpu' in get_model accordingly.
#
# if using faiss_als, make sure you have faiss installed. if annoy_als, annoy must be installed.

# %% [markdown]
# # Setup

# %%
import sys
sys.path.insert(0, '../src')
import preprocess
import utils
import random
import matplotlib.pyplot as plt
from collections import defaultdict
# %matplotlib inline
from matplotlib import rc
rc('figure', figsize=(16, 8), max_open_warning=False)
from surprise import SVD, SVDpp, NMF
from surprise import Dataset
from surprise.model_selection import cross_validate
from surprise import accuracy
from surprise.model_selection import train_test_split
import pandas as pd
import numpy as np
import implicit
import codecs
import json
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# # Implicit

# %%
import argparse
import codecs
import logging
import time

import numpy
import pandas
from scipy.sparse import coo_matrix

from implicit.als import AlternatingLeastSquares
from implicit.approximate_als import (AnnoyAlternatingLeastSquares, FaissAlternatingLeastSquares,
                                      NMSLibAlternatingLeastSquares)
from implicit.bpr import BayesianPersonalizedRanking
from implicit.nearest_neighbours import (BM25Recommender, CosineRecommender,
                                         TFIDFRecommender, bm25_weight)

# maps command line model argument to class name
MODELS = {"als":  AlternatingLeastSquares,
          "nmslib_als": NMSLibAlternatingLeastSquares,
          "annoy_als": AnnoyAlternatingLeastSquares,
          "faiss_als": FaissAlternatingLeastSquares,
          "tfidf": TFIDFRecommender,
          "cosine": CosineRecommender,
          "bpr": BayesianPersonalizedRanking,
          "bm25": BM25Recommender}



# NOT USING GPU?? CHANGE CODE HERE
def get_model(model_name,k,lam):
    model_class = MODELS.get(model_name)
    if not model_class:
        raise ValueError("Unknown Model '%s'" % model_name)

    # some default params
    if model_name == "faiss_als":
        params = {'factors': k, 'dtype': numpy.float32, 'use_gpu': False, 
                  'gpu': False,  # keyerror -1
                  "calculate_training_loss": True, "regularization": lam, "iterations": 15}
    elif issubclass(model_class, AlternatingLeastSquares):
        params = {'factors': k, 'dtype': numpy.float32, 'use_gpu': False, 
                  #'gpu': True,  # keyerror -1
                  "calculate_training_loss": True, "regularization": lam, "iterations": 15}
    elif model_name == "bm25":
        params = {'K1': 100, 'B': 0.5}
    elif model_name == "bpr":
        params = {'factors': 63, 'use_gpu': True}
    else:
        params = {}

    return model_class(**params)


def read_data(filename):
    """ Reads in the AMINER dataset, and returns a tuple of a pandas dataframe
    and a sparse matrix of artist/user/playcount """
    # read in triples of user/artist/playcount from the input dataset
    # get a model based off the input params
    start = time.time()
    print("reading data from %s"% (filename))
    data = pandas.read_table(filename,
                             usecols=[0, 1, 2],
                             names=['user', 'ref', 'cites'],
                             na_filter=False)

    # map each artist and user to a unique numeric value
    data['user'] = data['user'].astype("category")
    data['ref'] = data['ref'].astype("category")

    # create a sparse matrix of all the users/plays
    cites = coo_matrix((data['cites'].astype(numpy.float32),
                       (data['ref'].cat.codes.copy(),
                        data['user'].cat.codes.copy())))

    print("read data file in {}".format( time.time() - start))
    return data, cites

def calculate_recommendations(k, lam, input_filename, recommend_filename, similar_filename, model_name="als"):
    """ Generates artist recommendations for each user in the dataset """
    # train the model based off input params
    df, cites = read_data(input_filename)

    # create a model from the input data
    model = get_model(model_name,k,lam) 

    # if we're training an ALS based model, weight input for last.fm
    # by bm25
    if issubclass(model.__class__, AlternatingLeastSquares):
        # lets weight these models by bm25weight.
        print("weighting matrix by bm25_weight")
        #cites = bm25_weight(cites, K1=100, B=0.8)

        # also disable building approximate recommend index
        model.approximate_similar_items = True

    # this is actually disturbingly expensive:
    cites = cites.tocsr()

    print("training model {}".format(model_name))
    start = time.time()
    model.fit(cites) 
    print("trained model '%s' in %0.2f"%( model_name, time.time() - start))

    # generate recommendations for each user and write out to a file
    LEN_RECOMMENDATION = 50
    artists = dict(enumerate(df['ref'].cat.categories))
    start = time.time()
    user_cites = cites.T.tocsr()
    with codecs.open(recommend_filename, "w", "utf8") as o:
        for userid, username in enumerate(df['user'].cat.categories):
            for artistid, score in model.recommend(userid, user_cites, N=LEN_RECOMMENDATION):
                try:
                    o.write("%s\t%s\t%s\n" % (username, artists[artistid], score))
                except:
                    print("artistid {} had an error".format(artistid))
                    print(artistid in artists)
                    print(artistid in df['user'].cat.categories)
    print("generated recommendations in %0.2f"%(  time.time() - start))
    #'''
    
    # write out similar papers being cited
    start = time.time()
    user_count = df.groupby('ref').size()
    to_generate = list(artists)#sorted(list(artists), key=lambda x: -user_count[x])
    
    # This might be useful for visualizing what we learned so far
    LEN_SIMILAR_LIST = 10
    print("returning similar papers depending on being cited by which")
    # write out as a TSV of artistid, otherartistid, score
    with codecs.open(similar_filename, "w", "utf8") as o:
        i = 0
        for artistid in to_generate:
            try:
                artist = artists[artistid]
            except:
                print("artistid {} had an error".format(artistid))
            for other, score in model.similar_items(artistid, LEN_SIMILAR_LIST):
                try:
                    o.write("%s\t%s\t%s\n" % (artist, artists[other], score))
                except:
                    print("other {} had an error".format(other))
            i += 1
            if i > 1000:
                break
    print("generated similar artists in %0.2f"%(time.time() - start))
def start(k, lam, inputfile, outputfile, similarfile, model='faiss_als'):

    #if recommend:
    calculate_recommendations(k, lam, inputfile, outputfile, similarfile, model_name=model)

# %% [markdown]
# # Run it on debug data

# %%
logging.getLogger("implicit").addHandler(logging.FileHandler('output.log', 'a'))

# %%
logging.getLogger("implicit").setLevel(logging.DEBUG)

# %%
# !export OPENBLAS_NUM_THREADS=1
# !export MKL_NUM_THREADS=1

# %%
lam = 0.1
rank = 1000
start(rank, lam, '../dblp-ref/4fold/4fold_0_train.tsv', 
      "../als_4fold_rank_{}_lam_{}_recommend.tsv".format(rank,lam), 
      "../als_4fold_rank_{}_lam_{}_similar.tsv".format(rank,lam) , 
      model='als') # You can also choose 'faiss_als' which is best with gpu or 'annoy_als' with cpu
# Out:
# reading data from ../dblp-ref/4fold/4fold_0_train.tsv
# WARNING:root:OpenBLAS detected. Its highly recommend to set the environment variable 'export OPENBLAS_NUM_THREADS=1' to disable its internal multithreading
# DEBUG:implicit:Calculated transpose in 0.012s
# read data file in 0.21769332885742188
# weighting matrix by bm25_weight
# training model als
# DEBUG:implicit:initialize factors in 15.875524282455444
# DEBUG:implicit:finished iteration 0 in 56.825s
# DEBUG:implicit:loss at iteration 0 is 3.03743200514575e-05
# DEBUG:implicit:finished iteration 1 in 58.142s
# DEBUG:implicit:loss at iteration 1 is 2.8908748908120355e-05
# DEBUG:implicit:finished iteration 2 in 57.958s
# DEBUG:implicit:loss at iteration 2 is 2.8286725849942133e-05
# DEBUG:implicit:finished iteration 3 in 56.617s
# DEBUG:implicit:loss at iteration 3 is 2.8024533984340226e-05
# DEBUG:implicit:finished iteration 4 in 59.272s
# DEBUG:implicit:loss at iteration 4 is 2.7896592809426844e-05
# DEBUG:implicit:finished iteration 5 in 60.313s
# DEBUG:implicit:loss at iteration 5 is 2.7823736280656484e-05
# DEBUG:implicit:finished iteration 6 in 56.429s
# DEBUG:implicit:loss at iteration 6 is 2.777749852242715e-05
# DEBUG:implicit:finished iteration 7 in 56.636s
# DEBUG:implicit:loss at iteration 7 is 2.7745936250584448e-05
# DEBUG:implicit:finished iteration 8 in 57.012s
# DEBUG:implicit:loss at iteration 8 is 2.7723115137188007e-05
# DEBUG:implicit:finished iteration 9 in 56.443s
# DEBUG:implicit:loss at iteration 9 is 2.7705884066778703e-05
# DEBUG:implicit:finished iteration 10 in 53.665s
# DEBUG:implicit:loss at iteration 10 is 2.7692436807009663e-05
# DEBUG:implicit:finished iteration 11 in 55.901s
# DEBUG:implicit:loss at iteration 11 is 2.7681673271317134e-05
# DEBUG:implicit:finished iteration 12 in 55.016s
# DEBUG:implicit:loss at iteration 12 is 2.767288596320753e-05
# DEBUG:implicit:finished iteration 13 in 54.100s
# DEBUG:implicit:loss at iteration 13 is 2.7665597699542366e-05
# DEBUG:implicit:finished iteration 14 in 55.935s
# DEBUG:implicit:loss at iteration 14 is 2.7659475109269303e-05
# trained model 'als' in 927.12
# generated recommendations in 3862.98
# returning similar papers depending on being cited by which
# generated similar artists in 84.12

# %%
data = pandas.read_table("../als_4fold_rank_{}_lam_{}_recommend.tsv".format(rank,lam),
                             usecols=[0, 1, 2],
                             names=['user', 'ref', 'cites'],
                             na_filter=False)

# %%
from collections import defaultdict
result = defaultdict(list)

for index, row in data.iterrows():
    result[row['user']].append(row['ref'])

# %%
len(result)
# Out:
# 47018

# %%
trainDict = defaultdict(list)
trainDF = pandas.read_table('../dblp-ref/4fold/4fold_0_train.tsv',
                             usecols=[0, 1, 2],
                             names=['user', 'ref', 'cites'],
                             na_filter=False)
for index, row in trainDF.iterrows():
    trainDict[row['user']].append(row['ref'])
removeDict = defaultdict(list)
for key, values in result.items():
    for value in values:
        if value in trainDict[key]:
            removeDict[key].append(value)
for key, values in removeDict.items():
    for value in values:
        result[key].remove(value)

# %%
testDF = pandas.read_table('../dblp-ref/4fold/4fold_test.tsv',
                             usecols=[0, 1, 2],
                             names=['user', 'ref', 'cites'],
                             na_filter=False)
testDict = defaultdict(list)
for index, row in testDF.iterrows():
    testDict[row['user']].append(row['ref'])

# %%
validDF = pandas.read_table('../dblp-ref/4fold/4fold_0_val.tsv',
                             usecols=[0, 1, 2],
                             names=['user', 'ref', 'cites'],
                             na_filter=False)
validDict = defaultdict(list)
for index, row in validDF.iterrows():
    validDict[row['user']].append(row['ref'])

# %%
precisions_val = []
recalls_val = []
f1_val = []
klist = list(range(1,51))
for k in klist:
    topDict = dict()
    for key, value in result.items():
        if len(value) >= k:
            topDict[key]=value[:k]
        else:
            topDict[key]=value
    precisions, recalls = [], []
    for key, values in topDict.items():
        n_rel = len(validDict[key])
        if n_rel == 0:
            continue
        n_rec_k = len(values)
        n_rel_and_rec_k = 0
        for value in values:
            if value in validDict[key]:
                n_rel_and_rec_k += 1
        precisions.append( n_rel_and_rec_k / n_rec_k if n_rec_k != 0 else 0 )
        recalls.append( n_rel_and_rec_k / n_rel if n_rel != 0 else 0 )
    precision=np.sum(precisions)/len(precisions)
    recall=np.sum(recalls)/len(recalls)
    precisions_val.append(precision) 
    recalls_val.append(recall) 
    f1_val.append(2*(precision*recall)/(precision+recall))

# %%
precisions_test = []
recalls_test = []
f1_test = []
for k in klist:
    topDict = dict()
    for key, value in result.items():
        if len(value) >= k:
            topDict[key]=value[:k]
        else:
            topDict[key]=value
    precisions, recalls = [], []
    for key, values in topDict.items():
        n_rel = len(testDict[key])
        if n_rel == 0:
            continue
        n_rec_k = len(values)
        n_rel_and_rec_k = 0
        for value in values:
            if value in testDict[key]:
                n_rel_and_rec_k += 1
        precisions.append( n_rel_and_rec_k / n_rec_k if n_rec_k != 0 else 0 )
        recalls.append( n_rel_and_rec_k / n_rel if n_rel != 0 else 0 ) 
    precision=np.sum(precisions)/len(precisions)
    recall=np.sum(recalls)/len(recalls)
    precisions_test.append(precision)
    recalls_test.append(recall)
    f1_test.append(2*(precision*recall)/(precision+recall))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rc
rc('figure', figsize=(16, 8), max_open_warning=False)

# %%
plt.plot(klist, f1_val, label="validation")
plt.plot(klist, f1_test, label="test")
plt.legend()
plt.show()

# %%
plt.plot(precisions_val, recalls_val, label="validation")
plt.plot(precisions_test, recalls_test, label="test")
plt.legend()
plt.show()

# %%
similar = pandas.read_table( "../als_4fold_rank_{}_lam_{}_similar.tsv".format(rank,lam),
                             usecols=[0, 1, 2],
                             names=['user', 'ref', 'similarity'],
                             na_filter=False)

# %%
similar
# Out:
#         user      ref  similarity
# 0         30       30    1.000000
# 1         30  1525261    0.999204
# 2         30  2854192    0.999187
# 3         30  1357043    0.999170
# 4         30  2556123    0.999163
# 5         30  2561458    0.999163
# 6         30  1325400    0.999161
# 7         30  2471555    0.999160
# 8         30   860432    0.999158
# 9         30  1029727    0.999152
# 10       105      105    1.000000
# 11       105   566387    0.810489
# 12       105  1998326    0.810431
# 13       105  1900664    0.810431
# 14       105  2444533    0.810431
# 15       105   631579    0.810431
# 16       105  2167139    0.810431
# 17       105    35273    0.810431
# 18       105     4086    0.810431
# 19       105   368910    0.810431
# 20       117      117    1.000000
# 21       117   322184    0.999193
# 22       117  1431556    0.999184
# 23       117  2695997    0.999170
# 24       117  1826979    0.999164
# 25       117  2965525    0.999164
# 26       117  2701481    0.999161
# 27       117   711842    0.999153
# 28       117  2135328    0.999144
# 29       117  1496327    0.999134
# ...      ...      ...         ...
# 9980   19526   572569    1.000000
# 9981   19526  1439145    1.000000
# 9982   19526  2898323    1.000000
# 9983   19526    19526    1.000000
# 9984   19526  1772279    1.000000
# 9985   19526  1439754    1.000000
# 9986   19526  2238137    1.000000
# 9987   19526  2085231    1.000000
# 9988   19526  1661035    1.000000
# 9989   19526   158193    1.000000
# 9990   19550   515785    1.000000
# 9991   19550  1324583    1.000000
# 9992   19550    19550    1.000000
# 9993   19550  2592340    1.000000
# 9994   19550  2353401    1.000000
# 9995   19550    64313    1.000000
# 9996   19550   783754    1.000000
# 9997   19550  2305391    1.000000
# 9998   19550   150442    1.000000
# 9999   19550  1985397    1.000000
# 10000  19558    19558    1.000000
# 10001  19558  2560351    0.999979
# 10002  19558  2881526    0.999979
# 10003  19558  2493032    0.999979
# 10004  19558  2792020    0.999979
# 10005  19558  2734145    0.999979
# 10006  19558  1809319    0.999967
# 10007  19558  1313517    0.999966
# 10008  19558  1005349    0.999966
# 10009  19558   988181    0.999965
#
# [10010 rows x 3 columns]

# %%
def get_paper_names_given_numbering(datadir='../dblp-ref'):
    # When using surprise, it seems like we don't need this method.
    # This method assigns nonnegative integer numbers to each paper id,
    # and record it in a dictionary for efficient lookup.
    DBLP_LIST = [ datadir+'/dblp-ref-0.json',
        datadir+'/dblp-ref-1.json',
        datadir+'/dblp-ref-2.json',
        datadir+'/dblp-ref-3.json' ]
    
    name = dict()
    current_id = 0

    for data in DBLP_LIST:
        with open(data) as f:
            line = f.readline()
            while line:
                data = json.loads(line)
                name[current_id]   = data["title"]
                current_id += 1
                line = f.readline()

    return name

# %%
import json
name = get_paper_names_given_numbering()

# %%
i = 0
for index, row in similar.iterrows():
    print("paper 1: ", name[row['user']])
    print("paper 2: ", name[row['ref']])
    print("similarity: ", row['similarity'])
    print()
    i += 1
    if i >= 1000:
        break
# Out:
# paper 1:  Comparison of Fuzzy Edge Detectors Based on the Image Recognition Rate as Performance Index Calculated with Neural Networks
# paper 2:  Comparison of Fuzzy Edge Detectors Based on the Image Recognition Rate as Performance Index Calculated with Neural Networks
# similarity:  1.0000001
#
# paper 1:  Comparison of Fuzzy Edge Detectors Based on the Image Recognition Rate as Performance Index Calculated with Neural Networks
# paper 2:  On proving that certain languages are not ETOL
# similarity:  0.99920356
#
# paper 1:  Comparison of Fuzzy Edge Detectors Based on the Image Recognition Rate as Performance Index Calculated with Neural Networks
# paper 2:  SOLUTION SETS FOR EQUATIONS OVER FREE GROUPS ARE EDT0L LANGUAGES
# similarity:  0.9991868
#
# paper 1:  Comparison of Fuzzy Edge Detectors Based on the Image Recognition Rate as Performance Index Calculated with Neural Networks
# paper 2:  A Robust and Artifact Resistant Algorithm of Ultrawideband Imaging System for Breast Cancer Detection
# similarity:  0.9991699
#
# paper 1:  Comparison of Fuzzy Edge Detectors Based on the Image Recognition Rate as Performance Index Calculated with Neural Networks
# paper 2:  Lattice Boltzmann method study of bga bump arrangements on void formation
# similarity:  0.9991631
#
# paper 1:  Comparison of Fuzzy Edge Detectors Based on the Image Recognition Rate as Performance Index Calculated with Neural Networks
# paper 2:  A Radar-Based Breast Cancer Detection System Using CMOS Integrated Circuits
# similarity:  0.9991629000000001
#
# paper 1:  Comparison of Fuzzy Edge Detectors Based on the Image Recognition Rate as Performance Index Calculated with Neural Networks
# paper 2:  Integrative Modelling of the Influence of MAPK Network on Cancer Cell Fate Decision
# similarity:  0.9991608000000001
#
# paper 1:  Comparison of Fuzzy Edge Detectors Based on the Image Recognition Rate as Performance Index Calculated with Neural Networks
# paper 2:  Bistability and Oscillations in the Huang-Ferrell Model of MAPK Signaling
# similarity:  0.9991595999999999
#
# paper 1:  Comparison of Fuzzy Edge Detectors Based on the Image Recognition Rate as Performance Index Calculated with Neural Networks
# paper 2:  Multistability and robustness of the MAPK pathway
# similarity:  0.99915785
#
# paper 1:  Comparison of Fuzzy Edge Detectors Based on the Image Recognition Rate as Performance Index Calculated with Neural Networks
# paper 2:  A survey of medical imaging techniques used for breast cancer detection
# similarity:  0.99915195
#
# paper 1:  Context-Aware Staged Configuration of Process Variants@Runtime
# paper 2:  Context-Aware Staged Configuration of Process Variants@Runtime
# similarity:  1.0000001
#
# paper 1:  Context-Aware Staged Configuration of Process Variants@Runtime
# paper 2:  Reasoning about action I: a possible worlds approach
# similarity:  0.8104889000000001
#
# paper 1:  Context-Aware Staged Configuration of Process Variants@Runtime
# paper 2:  Handling obstacles in goal-oriented requirements engineering
# similarity:  0.810431
#
# paper 1:  Context-Aware Staged Configuration of Process Variants@Runtime
# paper 2:  Towards Adaptive Workflow Enactment Using Multiagent Systems
# similarity:  0.810431
#
# paper 1:  Context-Aware Staged Configuration of Process Variants@Runtime
# paper 2:  Process SEER: A Tool for Semantic Effect Annotation of Business Process Models
# similarity:  0.81043094
#
# paper 1:  Context-Aware Staged Configuration of Process Variants@Runtime
# paper 2:  Generating multi-objective optimized business process enactment plans
# similarity:  0.81043094
#
# paper 1:  Context-Aware Staged Configuration of Process Variants@Runtime
# paper 2:  Workflow Flexibility: The Forlorn Promise
# similarity:  0.81043094
#
# paper 1:  Context-Aware Staged Configuration of Process Variants@Runtime
# paper 2:  Enhancing Feasibility of Human-driven Processes by Transforming Process Models to Process Checklists
# similarity:  0.81043094
#
# paper 1:  Context-Aware Staged Configuration of Process Variants@Runtime
# paper 2:  Rule-Based Behavioral Reasoning on Semantic Business Processes
# similarity:  0.81043094
#
# paper 1:  Context-Aware Staged Configuration of Process Variants@Runtime
# paper 2:  On the semantics of service compositions
# similarity:  0.81043094
#
# paper 1:  Electronic Medical Record (EMR) Utilization for Public Health Surveillance
# paper 2:  Electronic Medical Record (EMR) Utilization for Public Health Surveillance
# similarity:  0.9999998999999999
#
# paper 1:  Electronic Medical Record (EMR) Utilization for Public Health Surveillance
# paper 2:  Newspaper page decomposition using a split and merge approach
# similarity:  0.99919295
#
# paper 1:  Electronic Medical Record (EMR) Utilization for Public Health Surveillance
# paper 2:  Time-scheduled delivery of computer health animations: "Installing" healthy habits of computer use.
# similarity:  0.9991838
#
# paper 1:  Electronic Medical Record (EMR) Utilization for Public Health Surveillance
# paper 2:  A scalable synchronous reload technique for wide division range multi modulus dividers
# similarity:  0.99916995
#
# paper 1:  Electronic Medical Record (EMR) Utilization for Public Health Surveillance
# paper 2:  Multibaric-multithermal ensemble molecular dynamics simulations.
# similarity:  0.99916446
#
# paper 1:  Electronic Medical Record (EMR) Utilization for Public Health Surveillance
# paper 2:  Realistic risk-mitigating recommendations via inverse classification
# similarity:  0.99916434
#
# paper 1:  Electronic Medical Record (EMR) Utilization for Public Health Surveillance
# paper 2:  Quantitative assess the driving forces on the grassland degradation in the Qinghai–Tibet Plateau, in China
# similarity:  0.9991607
#
# paper 1:  Electronic Medical Record (EMR) Utilization for Public Health Surveillance
# paper 2:  A Fine-Grained Outcome-Based Learning Path Model
# similarity:  0.9991529
#
# paper 1:  Electronic Medical Record (EMR) Utilization for Public Health Surveillance
# paper 2:  The evolution of robotics research
# similarity:  0.99914443
#
# paper 1:  Electronic Medical Record (EMR) Utilization for Public Health Surveillance
# paper 2:  An ensemble evolutionary constraint-based approach to understand the emergence of metabolic phenotypes
# similarity:  0.9991339
#
# paper 1:  Von Mises-Fisher Clustering Models
# paper 2:  Regressed Importance Sampling on Manifolds for Efficient Object Tracking
# similarity:  1.0000001
#
# paper 1:  Von Mises-Fisher Clustering Models
# paper 2:  Von Mises-Fisher Clustering Models
# similarity:  1.0
#
# paper 1:  Von Mises-Fisher Clustering Models
# paper 2:  Directional space-time oriented gradients for 3d visual pattern analysis
# similarity:  1.0
#
# paper 1:  Von Mises-Fisher Clustering Models
# paper 2:  Empirical Arithmetic Averaging Over the Compact Stiefel Manifold
# similarity:  1.0
#
# paper 1:  Von Mises-Fisher Clustering Models
# paper 2:  Locally time-invariant models of human activities using trajectories on the grassmannian
# similarity:  1.0
#
# paper 1:  Von Mises-Fisher Clustering Models
# paper 2:  The multivariate Watson distribution: Maximum-likelihood estimation and other aspects
# similarity:  1.0
#
# paper 1:  Von Mises-Fisher Clustering Models
# paper 2:  Bayesian Estimation of the von-Mises Fisher Mixture Model with Variational Inference
# similarity:  1.0
#
# paper 1:  Von Mises-Fisher Clustering Models
# paper 2:  Visual tracking via incremental self-tuning particle filtering on the affine group
# similarity:  1.0
#
# paper 1:  Von Mises-Fisher Clustering Models
# paper 2:  Generative model-based clustering of directional data
# similarity:  0.9999998999999999
#
# paper 1:  Von Mises-Fisher Clustering Models
# paper 2:  Spherical-Homoscedastic Distributions: The Equivalency of Spherical and Normal Distributions in Classification
# similarity:  0.9999998999999999
#
# paper 1:  Towards automatically generating graphical user interfaces from openEHR archetypes.
# paper 2:  Towards automatically generating graphical user interfaces from openEHR archetypes.
# similarity:  0.99999994
#
# paper 1:  Towards automatically generating graphical user interfaces from openEHR archetypes.
# paper 2:  A systematic review of the implementation and impact of asthma protocols
# similarity:  0.99999994
#
# paper 1:  Towards automatically generating graphical user interfaces from openEHR archetypes.
# paper 2:  Semantic interoperability in standardized electronic health record databases
# similarity:  0.9999998
#
# paper 1:  Towards automatically generating graphical user interfaces from openEHR archetypes.
# paper 2:  Dynamic generation of archetype-based user interfaces for queries on electronic health record databases
# similarity:  0.9999972
#
# paper 1:  Towards automatically generating graphical user interfaces from openEHR archetypes.
# paper 2:  Supporting chronic disease care quality: Design and implementation of a health service and its integration with electronic health records
# similarity:  0.99125576
#
# paper 1:  Towards automatically generating graphical user interfaces from openEHR archetypes.
# paper 2:  Extending the boundaries of IQ: Can collaboration with information management improve corporate governance
# similarity:  0.99087363
#
# paper 1:  Towards automatically generating graphical user interfaces from openEHR archetypes.
# paper 2:  A Methodology Supporting the Design and Evaluating the Final Quality of Data Warehouses.
# similarity:  0.99087244
#
# paper 1:  Towards automatically generating graphical user interfaces from openEHR archetypes.
# paper 2:  Effects of information quality on inventory management
# similarity:  0.9908718000000001
#
# paper 1:  Towards automatically generating graphical user interfaces from openEHR archetypes.
# paper 2:  Data-Driven Decision Making for New Drugs: A Collaborative Learning Experience
# similarity:  0.9908710999999999
#
# paper 1:  Towards automatically generating graphical user interfaces from openEHR archetypes.
# paper 2:  Business Intelligence and Organizational Decisions
# similarity:  0.9908703999999999
#
# paper 1:  Role of Software Product Customer in the Bring Your Own Device (BYOD) Trend: Empirical Observations on Software Quality Construction
# paper 2:  Profiting even more from open source
# similarity:  1.0000001
#
# paper 1:  Role of Software Product Customer in the Bring Your Own Device (BYOD) Trend: Empirical Observations on Software Quality Construction
# paper 2:  Profiting from open source
# similarity:  1.0000001
#
# paper 1:  Role of Software Product Customer in the Bring Your Own Device (BYOD) Trend: Empirical Observations on Software Quality Construction
# paper 2:  Performance of Open Source Projects.
# similarity:  1.0000001
#
# paper 1:  Role of Software Product Customer in the Bring Your Own Device (BYOD) Trend: Empirical Observations on Software Quality Construction
# paper 2:  Role of Software Product Customer in the Bring Your Own Device (BYOD) Trend: Empirical Observations on Software Quality Construction
# similarity:  1.0
#
# paper 1:  Role of Software Product Customer in the Bring Your Own Device (BYOD) Trend: Empirical Observations on Software Quality Construction
# paper 2:  Patterns for the distribution of power in FLOSS projects
# similarity:  1.0
#
# paper 1:  Role of Software Product Customer in the Bring Your Own Device (BYOD) Trend: Empirical Observations on Software Quality Construction
# paper 2:  The business of open source: missing patterns
# similarity:  1.0
#
# paper 1:  Role of Software Product Customer in the Bring Your Own Device (BYOD) Trend: Empirical Observations on Software Quality Construction
# paper 2:  What Makes Code Hard to Understand
# similarity:  1.0
#
# paper 1:  Role of Software Product Customer in the Bring Your Own Device (BYOD) Trend: Empirical Observations on Software Quality Construction
# paper 2:  Towards a pattern language for FLOSS development
# similarity:  1.0
#
# paper 1:  Role of Software Product Customer in the Bring Your Own Device (BYOD) Trend: Empirical Observations on Software Quality Construction
# paper 2:  Software rejuvenation via a multi-agent approach
# similarity:  0.9982901
#
# paper 1:  Role of Software Product Customer in the Bring Your Own Device (BYOD) Trend: Empirical Observations on Software Quality Construction
# paper 2:  Information Systems: Towards a System of Information Systems
# similarity:  0.9982901
#
# paper 1:  Learning to Merge Word Senses
# paper 2:  Infinite Hidden Relational Models
# similarity:  1.0000001
#
# paper 1:  Learning to Merge Word Senses
# paper 2:  Learning to Merge Word Senses
# similarity:  1.0
#
# paper 1:  Learning to Merge Word Senses
# paper 2:  Composing Relationships with Translations
# similarity:  1.0
#
# paper 1:  Learning to Merge Word Senses
# paper 2:  TripleRank: Ranking Semantic Web Data by Tensor Decomposition
# similarity:  0.966259
#
# paper 1:  Learning to Merge Word Senses
# paper 2:  Modelling Relational Data using Bayesian Clustered Tensor Factorization
# similarity:  0.95297396
#
# paper 1:  Learning to Merge Word Senses
# paper 2:  Knowledge base completion via search-based question answering
# similarity:  0.9516995999999999
#
# paper 1:  Learning to Merge Word Senses
# paper 2:  A Three-Way Model for Collective Learning on Multi-Relational Data
# similarity:  0.94873697
#
# paper 1:  Learning to Merge Word Senses
# paper 2:  Learning systems of concepts with an infinite relational model
# similarity:  0.94691104
#
# paper 1:  Learning to Merge Word Senses
# paper 2:  Knowledge graph embedding by translating on hyperplanes
# similarity:  0.94159836
#
# paper 1:  Learning to Merge Word Senses
# paper 2:  Some algebraic relations between involutions, convolutions and correlations, with applications to holographic memories
# similarity:  0.9394541
#
# paper 1:  A Roadmap for Navigating the Life Sciences Linked Open Data Cloud
# paper 2:  A Roadmap for Navigating the Life Sciences Linked Open Data Cloud
# similarity:  1.0000001
#
# paper 1:  A Roadmap for Navigating the Life Sciences Linked Open Data Cloud
# paper 2:  Why the Data Train Needs Semantic Rails
# similarity:  0.99279773
#
# paper 1:  A Roadmap for Navigating the Life Sciences Linked Open Data Cloud
# paper 2:  Describing LDP Applications with the Hydra Core Vocabulary.
# similarity:  0.9927976999999999
#
# paper 1:  A Roadmap for Navigating the Life Sciences Linked Open Data Cloud
# paper 2:  Linked Biomedical Dataspace: Lessons Learned Integrating Data for Drug Discovery
# similarity:  0.9927975
#
# paper 1:  A Roadmap for Navigating the Life Sciences Linked Open Data Cloud
# paper 2:  Linked data view methodology and application to BIM alignment and interoperability
# similarity:  0.9927975
#
# paper 1:  A Roadmap for Navigating the Life Sciences Linked Open Data Cloud
# paper 2:  A Generic RDF Transformation Software and Its Application to an Online Translation Service for Common Languages of Linked Data
# similarity:  0.99279743
#
# paper 1:  A Roadmap for Navigating the Life Sciences Linked Open Data Cloud
# paper 2:  Autonomous composition and execution of REST APIs for smart sensors
# similarity:  0.9927974
#
# paper 1:  A Roadmap for Navigating the Life Sciences Linked Open Data Cloud
# paper 2:  SQUIN: a traversal based query execution system for the web of linked data
# similarity:  0.9686302
#
# paper 1:  A Roadmap for Navigating the Life Sciences Linked Open Data Cloud
# paper 2:  SPLENDID: SPARQL endpoint federation exploiting VOID descriptions
# similarity:  0.96044147
#
# paper 1:  A Roadmap for Navigating the Life Sciences Linked Open Data Cloud
# paper 2:  HiBISCuS: Hypergraph-Based Source Selection for SPARQL Endpoint Federation
# similarity:  0.95669204
#
# paper 1:  A Minimum Description Length Technique for Semi-Supervised Time Series Classification
# paper 2:  A Minimum Description Length Technique for Semi-Supervised Time Series Classification
# similarity:  0.9999998
#
# paper 1:  A Minimum Description Length Technique for Semi-Supervised Time Series Classification
# paper 2:  An active learning-based SVM multi-class classification model
# similarity:  0.9883894
#
# paper 1:  A Minimum Description Length Technique for Semi-Supervised Time Series Classification
# paper 2:  Early classification on multivariate time series
# similarity:  0.9883894
#
# paper 1:  A Minimum Description Length Technique for Semi-Supervised Time Series Classification
# paper 2:  Combining committee-based semi-supervised learning and active learning
# similarity:  0.9883894
#
# paper 1:  A Minimum Description Length Technique for Semi-Supervised Time Series Classification
# paper 2:  Classification of multivariate time series using locality preserving projections
# similarity:  0.98838925
#
# paper 1:  A Minimum Description Length Technique for Semi-Supervised Time Series Classification
# paper 2:  Stability-Based Stopping Criterion for Active Learning
# similarity:  0.98838925
#
# paper 1:  A Minimum Description Length Technique for Semi-Supervised Time Series Classification
# paper 2:  Semi-supervised time series classification
# similarity:  0.98838925
#
# paper 1:  A Minimum Description Length Technique for Semi-Supervised Time Series Classification
# paper 2:  A Reverse Nearest Neighbor Based Active Semi-supervised Learning Method for Multivariate Time Series Classification
# similarity:  0.9883892
#
# paper 1:  A Minimum Description Length Technique for Semi-Supervised Time Series Classification
# paper 2:  BORDER: efficient computation of boundary points
# similarity:  0.9883892
#
# paper 1:  A Minimum Description Length Technique for Semi-Supervised Time Series Classification
# paper 2:  Confidence-based stopping criteria for active learning for data annotation
# similarity:  0.9883892
#
# paper 1:  Mapping-Based Merging of Schemas
# paper 2:  REQUEST: A Query Language for Customizing Recommendations
# similarity:  1.0000001
#
# paper 1:  Mapping-Based Merging of Schemas
# paper 2:  Genres of inquiry in design-science research: justification and evaluation of knowledge production
# similarity:  1.0
#
# paper 1:  Mapping-Based Merging of Schemas
# paper 2:  Applying Evaluations While Building the Artifact -- Experiences from the Development of Process Model Complexity Metrics
# similarity:  1.0
#
# paper 1:  Mapping-Based Merging of Schemas
# paper 2:  Mapping-Based Merging of Schemas
# similarity:  1.0
#
# paper 1:  Mapping-Based Merging of Schemas
# paper 2:  A method for taxonomy development and its application in information systems
# similarity:  1.0
#
# paper 1:  Mapping-Based Merging of Schemas
# paper 2:  Design science research contribution to business intelligence in the cloud - A systematic literature review
# similarity:  0.9999998999999999
#
# paper 1:  Mapping-Based Merging of Schemas
# paper 2:  Re-Visiting IS Design Science Artifacts: Making a Case for Critical Realism
# similarity:  0.9999998999999999
#
# paper 1:  Mapping-Based Merging of Schemas
# paper 2:  Emancipating instances from the tyranny of classes in information modeling
# similarity:  0.9898179
#
# paper 1:  Mapping-Based Merging of Schemas
# paper 2:  A method for designing value-infused citizen services in smart cities
# similarity:  0.9576318000000001
#
# paper 1:  Mapping-Based Merging of Schemas
# paper 2:  Building Understanding of Smart City Initiatives
# similarity:  0.9576318000000001
#
# paper 1:  Plausible repairs for inconsistent requirements
# paper 2:  Konfiguration von Versicherungsleistungen
# similarity:  1.0000001
#
# paper 1:  Plausible repairs for inconsistent requirements
# paper 2:  Human computation for constraint-based recommenders
# similarity:  1.0000001
#
# paper 1:  Plausible repairs for inconsistent requirements
# paper 2:  Biases in Decision Making.
# similarity:  0.99999994
#
# paper 1:  Plausible repairs for inconsistent requirements
# paper 2:  Assessing the maintainability of XCON-in-RIME: coping with the problems of a VERY large rule-base
# similarity:  0.99999994
#
# paper 1:  Plausible repairs for inconsistent requirements
# paper 2:  Personalized diagnoses for inconsistent user requirements
# similarity:  0.99999994
#
# paper 1:  Plausible repairs for inconsistent requirements
# paper 2:  Supporting the social dimension of shopping for personalized products through online sales configurators
# similarity:  0.99999994
#
# paper 1:  Plausible repairs for inconsistent requirements
# paper 2:  Consistency-based diagnosis of configuration knowledge bases
# similarity:  0.99999994
#
# paper 1:  Plausible repairs for inconsistent requirements
# paper 2:  Plausible repairs for inconsistent requirements
# similarity:  0.99999994
#
# paper 1:  Plausible repairs for inconsistent requirements
# paper 2:  WeCoTin --A practical logic-based sales configurator
# similarity:  0.99999994
#
# paper 1:  Plausible repairs for inconsistent requirements
# paper 2:  Constraint-based and SAT-based diagnosis of automotive configuration problems
# similarity:  0.99999994
#
# paper 1:  The generalization of AQM algorithms for queueing systems with bounded capacity
# paper 2:  The generalization of AQM algorithms for queueing systems with bounded capacity
# similarity:  1.0
#
# paper 1:  The generalization of AQM algorithms for queueing systems with bounded capacity
# paper 2:  Nonlinear RED: a simple yet efficient active queue management scheme
# similarity:  0.9998601
#
# paper 1:  The generalization of AQM algorithms for queueing systems with bounded capacity
# paper 2:  Observing Stochastic Processes, and Approximate Transform Inversion
# similarity:  0.99958646
#
# paper 1:  The generalization of AQM algorithms for queueing systems with bounded capacity
# paper 2:  Utilizing buffered YouTube playtime for QoE-oriented scheduling in OFDMA networks
# similarity:  0.99937904
#
# paper 1:  The generalization of AQM algorithms for queueing systems with bounded capacity
# paper 2:  Edge statistics-based image scale ratio and noise strength estimation in DCT-coded images
# similarity:  0.99937534
#
# paper 1:  The generalization of AQM algorithms for queueing systems with bounded capacity
# paper 2:  QoE-aware traffic management for mobile video delivery
# similarity:  0.99936175
#
# paper 1:  The generalization of AQM algorithms for queueing systems with bounded capacity
# paper 2:  Optimized Maximum Power Point Tracker for Fast-Changing Environmental Conditions
# similarity:  0.9993417
#
# paper 1:  The generalization of AQM algorithms for queueing systems with bounded capacity
# paper 2:  Wavelet Statistics of Sparse and Self-Similar Images ∗
# similarity:  0.99933153
#
# paper 1:  The generalization of AQM algorithms for queueing systems with bounded capacity
# paper 2:  Visualization of multidimensional data with collocated paired coordinates and general line coordinates
# similarity:  0.99932855
#
# paper 1:  The generalization of AQM algorithms for queueing systems with bounded capacity
# paper 2:  Linear control of nearly singularly perturbed hydropower plants
# similarity:  0.9993205
#
# paper 1:  Measuring the performance of online opponent models in automated bilateral negotiation
# paper 2:  Optimal incremental preference elicitation during negotiation
# similarity:  1.0000001
#
# paper 1:  Measuring the performance of online opponent models in automated bilateral negotiation
# paper 2:  The process of reaching agreement in meaning negotiation
# similarity:  1.0000001
#
# paper 1:  Measuring the performance of online opponent models in automated bilateral negotiation
# paper 2:  Algorithms for automated negotiations and their applications in information privacy
# similarity:  1.0
#
# paper 1:  Measuring the performance of online opponent models in automated bilateral negotiation
# paper 2:  Enabling Web Services Policy Negotiation with Privacy preserved using XACML
# similarity:  1.0
#
# paper 1:  Measuring the performance of online opponent models in automated bilateral negotiation
# paper 2:  Learning about the opponent in automated bilateral negotiation: a comprehensive survey of opponent modeling techniques
# similarity:  1.0
#
# paper 1:  Measuring the performance of online opponent models in automated bilateral negotiation
# paper 2:  Optimizing complex automated negotiation using sparse pseudo-input gaussian processes
# similarity:  1.0
#
# paper 1:  Measuring the performance of online opponent models in automated bilateral negotiation
# paper 2:  Privacy management in agent-based social networks
# similarity:  1.0
#
# paper 1:  Measuring the performance of online opponent models in automated bilateral negotiation
# paper 2:  Reaching Agreement in Security Policy Negotiation
# similarity:  1.0
#
# paper 1:  Measuring the performance of online opponent models in automated bilateral negotiation
# paper 2:  Implementing privacy negotiation techniques in e-commerce
# similarity:  1.0
#
# paper 1:  Measuring the performance of online opponent models in automated bilateral negotiation
# paper 2:  Policy Negotiation System Architecture for Privacy Protection
# similarity:  1.0
#
# paper 1:  Rational and convergent learning in stochastic games
# paper 2:  The Q -learning obstacle avoidance algorithm based on EKF-SLAM for NAO autonomous walking under unknown environments
# similarity:  1.0000001
#
# paper 1:  Rational and convergent learning in stochastic games
# paper 2:  Asymmetric multiagent reinforcement learning
# similarity:  1.0000001
#
# paper 1:  Rational and convergent learning in stochastic games
# paper 2:  A reinforcement learning with evolutionary state recruitment strategy for autonomous mobile robots control
# similarity:  1.0000001
#
# paper 1:  Rational and convergent learning in stochastic games
# paper 2:  Rational and convergent learning in stochastic games
# similarity:  1.0000001
#
# paper 1:  Rational and convergent learning in stochastic games
# paper 2:  Fast concurrent reinforcement learners
# similarity:  1.0
#
# paper 1:  Rational and convergent learning in stochastic games
# paper 2:  Learning multi-agent state space representations
# similarity:  1.0
#
# paper 1:  Rational and convergent learning in stochastic games
# paper 2:  Particle swarm optimization for unsupervised robotic learning
# similarity:  1.0
#
# paper 1:  Rational and convergent learning in stochastic games
# paper 2:  A Generalized Reinforcement-Learning Model: Convergence and Applications
# similarity:  1.0
#
# paper 1:  Rational and convergent learning in stochastic games
# paper 2:  Coordination in multiagent reinforcement learning: a Bayesian approach
# similarity:  1.0
#
# paper 1:  Rational and convergent learning in stochastic games
# paper 2:  Convergence Problems of General-Sum Multiagent Reinforcement Learning
# similarity:  1.0
#
# paper 1:  Analysing the cognitive effectiveness of the BPMN 2.0 visual notation
# paper 2:  Analysing the cognitive effectiveness of the BPMN 2.0 visual notation
# similarity:  1.0000001
#
# paper 1:  Analysing the cognitive effectiveness of the BPMN 2.0 visual notation
# paper 2:  A Framework for Empirical Evaluation of Model Comprehensibility
# similarity:  0.84027797
#
# paper 1:  Analysing the cognitive effectiveness of the BPMN 2.0 visual notation
# paper 2:  The EU-Project PROMOTE: A Process-Oriented Approach for Knowledge Management.
# similarity:  0.8123925999999999
#
# paper 1:  Analysing the cognitive effectiveness of the BPMN 2.0 visual notation
# paper 2:  A Business Process Meta-Model for Knowledge Identification Based on a Core Ontology
# similarity:  0.8123925999999999
#
# paper 1:  Analysing the cognitive effectiveness of the BPMN 2.0 visual notation
# paper 2:  A UML 2 Profile for Event Driven Process Chains
# similarity:  0.8123925999999999
#
# paper 1:  Analysing the cognitive effectiveness of the BPMN 2.0 visual notation
# paper 2:  Towards Knowledge-Intensive Processes Representation
# similarity:  0.81239253
#
# paper 1:  Analysing the cognitive effectiveness of the BPMN 2.0 visual notation
# paper 2:  Process Oriented Knowledge Management: A Service Based Approach.
# similarity:  0.81239253
#
# paper 1:  Analysing the cognitive effectiveness of the BPMN 2.0 visual notation
# paper 2:  A Comparison of XML Interchange Formats for Business Process Modelling
# similarity:  0.81239253
#
# paper 1:  Analysing the cognitive effectiveness of the BPMN 2.0 visual notation
# paper 2:  Knowledge modelling in weakly‐structured business processes
# similarity:  0.8123924
#
# paper 1:  Analysing the cognitive effectiveness of the BPMN 2.0 visual notation
# paper 2:  Analyzing Knowledge Transfer Effectiveness--An Agent-Oriented Modeling Approach
# similarity:  0.8123924
#
# paper 1:  Spectral clustering as an automated SOM segmentation tool
# paper 2:  An Interactive, Example-Based, Visual Clustering System
# similarity:  1.0000002000000001
#
# paper 1:  Spectral clustering as an automated SOM segmentation tool
# paper 2:  An integrated growing-pruning method for feedforward network training
# similarity:  1.0000002000000001
#
# paper 1:  Spectral clustering as an automated SOM segmentation tool
# paper 2:  Spectral clustering as an automated SOM segmentation tool
# similarity:  1.0000002000000001
#
# paper 1:  Spectral clustering as an automated SOM segmentation tool
# paper 2:  A structure optimisation algorithm for feedforward neural network construction
# similarity:  1.0000001
#
# paper 1:  Spectral clustering as an automated SOM segmentation tool
# paper 2:  TreeGNG - Hierarchical Topological Clustering
# similarity:  1.0000001
#
# paper 1:  Spectral clustering as an automated SOM segmentation tool
# paper 2:  An efficient self-organizing map (E-SOM) learning algorithm using group of neurons
# similarity:  1.0000001
#
# paper 1:  Spectral clustering as an automated SOM segmentation tool
# paper 2:  A density-based cluster validity approach using multi-representatives
# similarity:  1.0000001
#
# paper 1:  Spectral clustering as an automated SOM segmentation tool
# paper 2:  Competitive neural networks on message‐passing parallel computers
# similarity:  1.0000001
#
# paper 1:  Spectral clustering as an automated SOM segmentation tool
# paper 2:  Automatic Cluster Detection in Kohonen's SOM
# similarity:  1.0000001
#
# paper 1:  Spectral clustering as an automated SOM segmentation tool
# paper 2:  Hierarchical growing cell structures: TreeGCS
# similarity:  1.0000001
#
# paper 1:  Determinant of the Generalized Lucas RSFMLR Circulant Matrices in Communication
# paper 2:  Determinant of the Generalized Lucas RSFMLR Circulant Matrices in Communication
# similarity:  1.0000001
#
# paper 1:  Determinant of the Generalized Lucas RSFMLR Circulant Matrices in Communication
# paper 2:  On Explicit Determinants of RFPLR and RFPLL Circulant Matrices Involving Pell Numbers in Information Theory
# similarity:  0.99982715
#
# paper 1:  Determinant of the Generalized Lucas RSFMLR Circulant Matrices in Communication
# paper 2:  A note on inversion of Toeplitz matrices
# similarity:  0.9997436
#
# paper 1:  Determinant of the Generalized Lucas RSFMLR Circulant Matrices in Communication
# paper 2:  On sinc discretization and banded preconditioning for linear third‐order ordinary differential equations
# similarity:  0.9996082000000001
#
# paper 1:  Determinant of the Generalized Lucas RSFMLR Circulant Matrices in Communication
# paper 2:  Lossless Reduced Cutset Coding of Markov Random Fields
# similarity:  0.99956447
#
# paper 1:  Determinant of the Generalized Lucas RSFMLR Circulant Matrices in Communication
# paper 2:  Minimizing Energy Consumption in Hexapod Robots
# similarity:  0.9995459999999999
#
# paper 1:  Determinant of the Generalized Lucas RSFMLR Circulant Matrices in Communication
# paper 2:  Generation of discontinuous gaits for quadruped walking vehicles
# similarity:  0.999526
#
# paper 1:  Determinant of the Generalized Lucas RSFMLR Circulant Matrices in Communication
# paper 2:  Graphs without four‐cycles
# similarity:  0.9994735
#
# paper 1:  Determinant of the Generalized Lucas RSFMLR Circulant Matrices in Communication
# paper 2:  Rule-based detection of intrathoracic airway trees
# similarity:  0.99945426
#
# paper 1:  Determinant of the Generalized Lucas RSFMLR Circulant Matrices in Communication
# paper 2:  Adjacency matrices of polarity graphs and of other C4-free graphs of large size
# similarity:  0.99944514
#
# paper 1:  LCM: An Efficient Algorithm for Enumerating Frequent Closed Item Sets.
# paper 2:  LCM: An Efficient Algorithm for Enumerating Frequent Closed Item Sets.
# similarity:  1.0
#
# paper 1:  LCM: An Efficient Algorithm for Enumerating Frequent Closed Item Sets.
# paper 2:  A Reconfigurable Platform for Frequent Pattern Mining
# similarity:  1.0
#
# paper 1:  LCM: An Efficient Algorithm for Enumerating Frequent Closed Item Sets.
# paper 2:  A Real-Time FPGA-Based Accelerator for ECG Analysis and Diagnosis Using Association-Rule Mining
# similarity:  1.0
#
# paper 1:  LCM: An Efficient Algorithm for Enumerating Frequent Closed Item Sets.
# paper 2:  Hardware-Enhanced Association Rule Mining with Hashing and Pipelining
# similarity:  1.0
#
# paper 1:  LCM: An Efficient Algorithm for Enumerating Frequent Closed Item Sets.
# paper 2:  FPGA Acceleration for Intersection Computation in Frequent Itemset Mining
# similarity:  1.0
#
# paper 1:  LCM: An Efficient Algorithm for Enumerating Frequent Closed Item Sets.
# paper 2:  Accelerating frequent itemset mining on graphics processing units
# similarity:  1.0
#
# paper 1:  LCM: An Efficient Algorithm for Enumerating Frequent Closed Item Sets.
# paper 2:  Design and Analysis of a Reconfigurable Platform for Frequent Pattern Mining
# similarity:  0.99999994
#
# paper 1:  LCM: An Efficient Algorithm for Enumerating Frequent Closed Item Sets.
# paper 2:  An FPGA-Based Accelerator for Frequent Itemset Mining
# similarity:  0.99999994
#
# paper 1:  LCM: An Efficient Algorithm for Enumerating Frequent Closed Item Sets.
# paper 2:  Mining exceptional relationships with grammar-guided genetic programming
# similarity:  0.9962995000000001
#
# paper 1:  LCM: An Efficient Algorithm for Enumerating Frequent Closed Item Sets.
# paper 2:  Penguins Search Optimisation Algorithm for Association Rules Mining
# similarity:  0.99629945
#
# paper 1:  Using BPEL to realize business processes for an internet of things
# paper 2:  Towards runtime migration of WS-BPEL processes
# similarity:  1.0000001
#
# paper 1:  Using BPEL to realize business processes for an internet of things
# paper 2:  Design and implementation of the YAWL system
# similarity:  1.0
#
# paper 1:  Using BPEL to realize business processes for an internet of things
# paper 2:  APDL: A reference XML schema for process-centered definition of RFID solutions
# similarity:  1.0
#
# paper 1:  Using BPEL to realize business processes for an internet of things
# paper 2:  Modeling and execution of event stream processing in business processes
# similarity:  1.0
#
# paper 1:  Using BPEL to realize business processes for an internet of things
# paper 2:  Process-based design and integration of wireless sensor network applications
# similarity:  1.0
#
# paper 1:  Using BPEL to realize business processes for an internet of things
# paper 2:  Service selection and composition in opportunistic networks
# similarity:  1.0
#
# paper 1:  Using BPEL to realize business processes for an internet of things
# paper 2:  Towards a context-aware solution for device failures in service-oriented workflow
# similarity:  1.0
#
# paper 1:  Using BPEL to realize business processes for an internet of things
# paper 2:  Using BPEL to realize business processes for an internet of things
# similarity:  0.99999994
#
# paper 1:  Using BPEL to realize business processes for an internet of things
# paper 2:  Towards Flexible Process Support on Mobile Devices
# similarity:  0.99999994
#
# paper 1:  Using BPEL to realize business processes for an internet of things
# paper 2:  A Middleware for Discovering Proximity-Based Service-Oriented Industrial Internet of Things
# similarity:  0.99999994
#
# paper 1:  Where are the really hard manipulation problems? the phase transition in manipulating the veto rule
# paper 2:  Where are the really hard manipulation problems? the phase transition in manipulating the veto rule
# similarity:  0.99999994
#
# paper 1:  Where are the really hard manipulation problems? the phase transition in manipulating the veto rule
# paper 2:  Phase Transitions and Backbones of 3-SAT and Maximum 3-SAT
# similarity:  0.99999714
#
# paper 1:  Where are the really hard manipulation problems? the phase transition in manipulating the veto rule
# paper 2:  The binocular neural mechanism: disparity coding schemes and population coding
# similarity:  0.99999106
#
# paper 1:  Where are the really hard manipulation problems? the phase transition in manipulating the veto rule
# paper 2:  An upper (lower) bound for Max (Min) CSP
# similarity:  0.9999819999999999
#
# paper 1:  Where are the really hard manipulation problems? the phase transition in manipulating the veto rule
# paper 2:  The Number of Solutions for Random Regular NAE-SAT
# similarity:  0.99997026
#
# paper 1:  Where are the really hard manipulation problems? the phase transition in manipulating the veto rule
# paper 2:  Experimental analyses on phase transitions in compiling satisfiability problems
# similarity:  0.99996257
#
# paper 1:  Where are the really hard manipulation problems? the phase transition in manipulating the veto rule
# paper 2:  A tighter upper bound for random MAX 2-SAT
# similarity:  0.99996245
#
# paper 1:  Where are the really hard manipulation problems? the phase transition in manipulating the veto rule
# paper 2:  Random MAX SAT, random MAX CUT, and their phase transitions
# similarity:  0.9999615
#
# paper 1:  Where are the really hard manipulation problems? the phase transition in manipulating the veto rule
# paper 2:  The TSP phase transition
# similarity:  0.99996024
#
# paper 1:  Where are the really hard manipulation problems? the phase transition in manipulating the veto rule
# paper 2:  A general model and thresholds for random constraint satisfaction problems
# similarity:  0.99995816
#
# paper 1:  Target Monitoring in Wireless Sensor Networks: A Localized Approach.
# paper 2:  Target Monitoring in Wireless Sensor Networks: A Localized Approach.
# similarity:  1.0000001
#
# paper 1:  Target Monitoring in Wireless Sensor Networks: A Localized Approach.
# paper 2:  Energy-efficient connected-coverage in wireless sensor networks
# similarity:  1.0000001
#
# paper 1:  Target Monitoring in Wireless Sensor Networks: A Localized Approach.
# paper 2:  DARE: evaluating Data Accuracy using node REputation
# similarity:  1.0000001
#
# paper 1:  Target Monitoring in Wireless Sensor Networks: A Localized Approach.
# paper 2:  Achieving minimum coverage breach under bandwidth constraints in wireless sensor networks
# similarity:  1.0
#
# paper 1:  Target Monitoring in Wireless Sensor Networks: A Localized Approach.
# paper 2:  Connected coverage in WSNs based on critical targets
# similarity:  1.0
#
# paper 1:  Target Monitoring in Wireless Sensor Networks: A Localized Approach.
# paper 2:  A survey on energy efficient techniques in wireless sensor networks
# similarity:  1.0
#
# paper 1:  Target Monitoring in Wireless Sensor Networks: A Localized Approach.
# paper 2:  Distributed Energy Optimization for Target Tracking in Wireless Sensor Networks
# similarity:  1.0
#
# paper 1:  Target Monitoring in Wireless Sensor Networks: A Localized Approach.
# paper 2:  Distributed Deployment Strategies for Improved Coverage in a Network of Mobile Sensors With Prioritized Sensing Field
# similarity:  1.0
#
# paper 1:  Target Monitoring in Wireless Sensor Networks: A Localized Approach.
# paper 2:  An Ant Colony Optimization Approach for Maximizing the Lifetime of Heterogeneous Wireless Sensor Networks
# similarity:  0.99999994
#
# paper 1:  Target Monitoring in Wireless Sensor Networks: A Localized Approach.
# paper 2:  Solving coverage problems in wireless sensor networks using cover sets
# similarity:  0.99999994
#
# paper 1:  The game ontology project: supporting learning while contributing authentically to game studies
# paper 2:  Using semantics to improve the design of game worlds
# similarity:  1.0000001
#
# paper 1:  The game ontology project: supporting learning while contributing authentically to game studies
# paper 2:  Playing with Data: Procedural Generation of Adventures from Open Data
# similarity:  1.0
#
# paper 1:  The game ontology project: supporting learning while contributing authentically to game studies
# paper 2:  Aesthetic considerations for automated platformer design
# similarity:  1.0
#
# paper 1:  The game ontology project: supporting learning while contributing authentically to game studies
# paper 2:  Toward supporting stories with procedurally generated game worlds
# similarity:  1.0
#
# paper 1:  The game ontology project: supporting learning while contributing authentically to game studies
# paper 2:  The game ontology project: supporting learning while contributing authentically to game studies
# similarity:  1.0
#
# paper 1:  The game ontology project: supporting learning while contributing authentically to game studies
# paper 2:  Linking in-game events and entities to social data on the Web
# similarity:  0.9999998999999999
#
# paper 1:  The game ontology project: supporting learning while contributing authentically to game studies
# paper 2:  An ontology for videogame interoperability
# similarity:  0.9999998999999999
#
# paper 1:  The game ontology project: supporting learning while contributing authentically to game studies
# paper 2:  Designing Semantic Game Worlds
# similarity:  0.9999998999999999
#
# paper 1:  The game ontology project: supporting learning while contributing authentically to game studies
# paper 2:  A semantic generation framework for enabling adaptive game worlds
# similarity:  0.9999998
#
# paper 1:  The game ontology project: supporting learning while contributing authentically to game studies
# paper 2:  A large-scale classification of English verbs
# similarity:  0.9999998
#
# paper 1:  Towards Elastic Component-Based Cloud Applications
# paper 2:  Towards Elastic Component-Based Cloud Applications
# similarity:  1.0000001
#
# paper 1:  Towards Elastic Component-Based Cloud Applications
# paper 2:  Towards DevOps in the Embedded Systems Domain: Why is It So Hard?
# similarity:  1.0000001
#
# paper 1:  Towards Elastic Component-Based Cloud Applications
# paper 2:  DevOpSlang – Bridging the Gap between Development and Operations
# similarity:  1.0000001
#
# paper 1:  Towards Elastic Component-Based Cloud Applications
# paper 2:  A new business model of custom software development for agile software development
# similarity:  1.0000001
#
# paper 1:  Towards Elastic Component-Based Cloud Applications
# paper 2:  Digital Service Platform for Networked Enterprises Collaboration: A Case Study of the NEMESYS Project
# similarity:  1.0
#
# paper 1:  Towards Elastic Component-Based Cloud Applications
# paper 2:  Continuous software engineering and beyond: trends and challenges
# similarity:  1.0
#
# paper 1:  Towards Elastic Component-Based Cloud Applications
# paper 2:  On Autonomic Platform-as-a-Service: Characterisation and Conceptual Model
# similarity:  0.9999998999999999
#
# paper 1:  Towards Elastic Component-Based Cloud Applications
# paper 2:  Thematic series on service composition for the future internet
# similarity:  0.9999998999999999
#
# paper 1:  Towards Elastic Component-Based Cloud Applications
# paper 2:  Organisational Aspects and Anatomy of an Attack on NFC/HCE Mobile Payment Systems
# similarity:  0.9999998999999999
#
# paper 1:  Towards Elastic Component-Based Cloud Applications
# paper 2:  Elastic component-based applications in PaaS clouds
# similarity:  0.9999998
#
# paper 1:  Checking Termination of Logic Programs with Function Symbols through Linear Constraints
# paper 2:  Querying and repairing inconsistent databases under three-valued semantics
# similarity:  1.0000002000000001
#
# paper 1:  Checking Termination of Logic Programs with Function Symbols through Linear Constraints
# paper 2:  DART: a data acquisition and repairing tool
# similarity:  1.0000001
#
# paper 1:  Checking Termination of Logic Programs with Function Symbols through Linear Constraints
# paper 2:  Checking Chase Termination: Cyclicity Analysis and Rewriting Techniques
# similarity:  1.0000001
#
# paper 1:  Checking Termination of Logic Programs with Function Symbols through Linear Constraints
# paper 2:  Anatomy of the chase
# similarity:  1.0000001
#
# paper 1:  Checking Termination of Logic Programs with Function Symbols through Linear Constraints
# paper 2:  Polynomial time queries over inconsistent databases with functional dependencies and foreign keys
# similarity:  1.0000001
#
# paper 1:  Checking Termination of Logic Programs with Function Symbols through Linear Constraints
# paper 2:  On repairing and querying inconsistent probabilistic spatio-temporal databases
# similarity:  1.0000001
#
# paper 1:  Checking Termination of Logic Programs with Function Symbols through Linear Constraints
# paper 2:  One More Decidable Class of Finitely Ground Programs
# similarity:  1.0000001
#
# paper 1:  Checking Termination of Logic Programs with Function Symbols through Linear Constraints
# paper 2:  Revision programming
# similarity:  1.0000001
#
# paper 1:  Checking Termination of Logic Programs with Function Symbols through Linear Constraints
# paper 2:  Checking Termination of Logic Programs with Function Symbols through Linear Constraints
# similarity:  1.0000001
#
# paper 1:  Checking Termination of Logic Programs with Function Symbols through Linear Constraints
# paper 2:  Chase termination: a constraints rewriting approach
# similarity:  1.0000001
#
# paper 1:  An Application of the ψ-Theory to the Analysis of Business Process Models
# paper 2:  Enhancing the Formal Foundations of BPMN by Enterprise Ontology
# similarity:  1.0
#
# paper 1:  An Application of the ψ-Theory to the Analysis of Business Process Models
# paper 2:  An Application of the ψ-Theory to the Analysis of Business Process Models
# similarity:  0.99999994
#
# paper 1:  An Application of the ψ-Theory to the Analysis of Business Process Models
# paper 2:  Can BPMN Be Used for Making Simulation Models
# similarity:  0.99999994
#
# paper 1:  An Application of the ψ-Theory to the Analysis of Business Process Models
# paper 2:  What Does DEMO Do? A Qualitative Analysis about DEMO in Practice: Founders, Modellers and Beneficiaries
# similarity:  0.9999998
#
# paper 1:  An Application of the ψ-Theory to the Analysis of Business Process Models
# paper 2:  Empirical Study of Applying the DEMO Method for Improving BPMN Process Models in Academic Environment
# similarity:  0.99999964
#
# paper 1:  An Application of the ψ-Theory to the Analysis of Business Process Models
# paper 2:  A New Action Rule Syntax for DEmo MOdels Based Automatic worKflow procEss geneRation (DEMOBAKER)
# similarity:  0.9984668
#
# paper 1:  An Application of the ψ-Theory to the Analysis of Business Process Models
# paper 2:  Combining DEMO and Normalized Systems for Developing Agile Enterprise Information Systems
# similarity:  0.99259865
#
# paper 1:  An Application of the ψ-Theory to the Analysis of Business Process Models
# paper 2:  Towards the Ontological Foundations for the Software Executable DEMO Action and Fact Models
# similarity:  0.9925973
#
# paper 1:  An Application of the ψ-Theory to the Analysis of Business Process Models
# paper 2:  Positioning the Normalized Systems Theory in a Design Theory Framework
# similarity:  0.99259675
#
# paper 1:  An Application of the ψ-Theory to the Analysis of Business Process Models
# paper 2:  Detailed Analysis of REA Ontology
# similarity:  0.9917019
#
# paper 1:  Arguing with justifications between collaborating agents
# paper 2:  Probabilistic Justification Logic
# similarity:  1.0000001
#
# paper 1:  Arguing with justifications between collaborating agents
# paper 2:  Bipolar Possibility Theory as a Basis for a Logic of Desires and Beliefs
# similarity:  1.0
#
# paper 1:  Arguing with justifications between collaborating agents
# paper 2:  Justification Logic
# similarity:  1.0
#
# paper 1:  Arguing with justifications between collaborating agents
# paper 2:  Arguing with justifications between collaborating agents
# similarity:  1.0
#
# paper 1:  Arguing with justifications between collaborating agents
# paper 2:  First steps towards probabilistic justification logic
# similarity:  1.0
#
# paper 1:  Arguing with justifications between collaborating agents
# paper 2:  Distributed Knowledge Justification Logics
# similarity:  0.99999994
#
# paper 1:  Arguing with justifications between collaborating agents
# paper 2:  The Logic of Uncertain Justifications
# similarity:  0.99999994
#
# paper 1:  Arguing with justifications between collaborating agents
# paper 2:  A modal account of similarity-based reasoning
# similarity:  0.99999994
#
# paper 1:  Arguing with justifications between collaborating agents
# paper 2:  Introducing Justification into Epistemic Logic
# similarity:  0.99999994
#
# paper 1:  Arguing with justifications between collaborating agents
# paper 2:  Quantitative modal logic and possibilistic reasoning
# similarity:  0.99999994
#
# ...
# similarity:  1.0000001
#
# paper 1:  Parameter Optimization of Local-Concentration Model for Spam Detection by Using Fireworks Algorithm
# paper 2:  Parameter Optimization of Local-Concentration Model for Spam Detection by Using Fireworks Algorithm
# similarity:  1.0000001
#
# paper 1:  Parameter Optimization of Local-Concentration Model for Spam Detection by Using Fireworks Algorithm
# paper 2:  The Effect of Information Utilization: Introducing a Novel Guiding Spark in the Fireworks Algorithm
# similarity:  1.0
#
# paper 1:  Parameter Optimization of Local-Concentration Model for Spam Detection by Using Fireworks Algorithm
# paper 2:  A multi-objective evolutionary approach to image quality/compression trade-off in JPEG baseline algorithm
# similarity:  1.0
#
# paper 1:  Parameter Optimization of Local-Concentration Model for Spam Detection by Using Fireworks Algorithm
# paper 2:  Support Vector Machine Parameters Optimization by Enhanced Fireworks Algorithm
# similarity:  0.99999994
#
# paper 1:  Parameter Optimization of Local-Concentration Model for Spam Detection by Using Fireworks Algorithm
# paper 2:  A Cooperative Framework for Fireworks Algorithm
# similarity:  0.99999994
#
# paper 1:  Parameter Optimization of Local-Concentration Model for Spam Detection by Using Fireworks Algorithm
# paper 2:  On the design of a novel JPEG quantization table for improved feature detection performance
# similarity:  0.99999994
#
# paper 1:  Parameter Optimization of Local-Concentration Model for Spam Detection by Using Fireworks Algorithm
# paper 2:  Enhanced Fireworks Algorithm
# similarity:  0.9999998
#
# paper 1:  Parameter Optimization of Local-Concentration Model for Spam Detection by Using Fireworks Algorithm
# paper 2:  A High Capacity Steganographic Method Based on Quantization Table Modification and F5 Algorithm
# similarity:  0.9999998
#
# paper 1:  A Knowledge Model Sharing Based Approach to Privacy-Preserving Data Mining
# paper 2:  Privacy-preserving SVM using nonlinear kernels on horizontally partitioned data
# similarity:  1.0000001
#
# paper 1:  A Knowledge Model Sharing Based Approach to Privacy-Preserving Data Mining
# paper 2:  Classification Using Streaming Random Forests
# similarity:  1.0000001
#
# paper 1:  A Knowledge Model Sharing Based Approach to Privacy-Preserving Data Mining
# paper 2:  Privacy-Preserving Data Stream Classification
# similarity:  1.0
#
# paper 1:  A Knowledge Model Sharing Based Approach to Privacy-Preserving Data Mining
# paper 2:  Providing k-anonymity in data mining
# similarity:  1.0
#
# paper 1:  A Knowledge Model Sharing Based Approach to Privacy-Preserving Data Mining
# paper 2:  Privacy and ownership preserving of outsourced medical data
# similarity:  0.99999994
#
# paper 1:  A Knowledge Model Sharing Based Approach to Privacy-Preserving Data Mining
# paper 2:  Continuous privacy preserving publishing of data streams
# similarity:  0.99999994
#
# paper 1:  A Knowledge Model Sharing Based Approach to Privacy-Preserving Data Mining
# paper 2:  A Systematic Comparison and Evaluation of k-Anonymization Algorithms for Practitioners
# similarity:  0.99999994
#
# paper 1:  A Knowledge Model Sharing Based Approach to Privacy-Preserving Data Mining
# paper 2:  A Survey of Privacy-Preserving Methods Across Horizontally Partitioned Data
# similarity:  0.99999994
#
# paper 1:  A Knowledge Model Sharing Based Approach to Privacy-Preserving Data Mining
# paper 2:  A Knowledge Model Sharing Based Approach to Privacy-Preserving Data Mining
# similarity:  0.99999994
#
# paper 1:  A Knowledge Model Sharing Based Approach to Privacy-Preserving Data Mining
# paper 2:  Classifier Ensemble for Imbalanced Data Stream Classification
# similarity:  0.99999994
#
# paper 1:  Semantic Alignment of Business Processes.
# paper 2:  Business process compliance checking --- applying and evaluating a generic pattern matching approach for conceptual models in the financial sector
# similarity:  1.0
#
# paper 1:  Semantic Alignment of Business Processes.
# paper 2:  Discovering Business Process Similarities: An Empirical Study with SAP Best Practice Business Processes
# similarity:  1.0
#
# paper 1:  Semantic Alignment of Business Processes.
# paper 2:  Measuring the Compliance of Processes with Reference Models
# similarity:  1.0
#
# paper 1:  Semantic Alignment of Business Processes.
# paper 2:  From Measuring the Quality of Labels in Process Models to a Discourse on Process Model Quality: A Case Study
# similarity:  1.0
#
# paper 1:  Semantic Alignment of Business Processes.
# paper 2:  Semantic Alignment of Business Processes.
# similarity:  0.99999994
#
# paper 1:  Semantic Alignment of Business Processes.
# paper 2:  Report: The Process Model Matching Contest 2013
# similarity:  0.98954046
#
# paper 1:  Semantic Alignment of Business Processes.
# paper 2:  Extracting a domain-specific ontology from a corporate intranet
# similarity:  0.9644391999999999
#
# paper 1:  Semantic Alignment of Business Processes.
# paper 2:  AN APPROACH FOR SEMANTIC BUSINESS PROCESS MODEL MATCHING USING SUPERVISED MACHINE LEARNING
# similarity:  0.96443915
#
# paper 1:  Semantic Alignment of Business Processes.
# paper 2:  Automatic interpretation of noun compounds using wordnet similarity
# similarity:  0.96443915
#
# paper 1:  Semantic Alignment of Business Processes.
# paper 2:  Interpreting Semantic Relations in Noun Compounds via Verb Semantics
# similarity:  0.9644389999999999
#
# paper 1:  Monte Carlo Value Iteration for Continuous-State POMDPs
# paper 2:  Solving Continuous-State POMDPs via Density Projection
# similarity:  1.0000001
#
# paper 1:  Monte Carlo Value Iteration for Continuous-State POMDPs
# paper 2:  Unmanned Aircraft Collision Avoidance using Continuous-State POMDPs.
# similarity:  1.0000001
#
# paper 1:  Monte Carlo Value Iteration for Continuous-State POMDPs
# paper 2:  Covering Number for Efficient Heuristic-based POMDP Planning
# similarity:  1.0000001
#
# paper 1:  Monte Carlo Value Iteration for Continuous-State POMDPs
# paper 2:  Point-Based Value Iteration for Continuous POMDPs
# similarity:  1.0000001
#
# paper 1:  Monte Carlo Value Iteration for Continuous-State POMDPs
# paper 2:  Intention-aware online POMDP planning for autonomous driving in a crowd
# similarity:  1.0000001
#
# paper 1:  Monte Carlo Value Iteration for Continuous-State POMDPs
# paper 2:  Point-based POMDP algorithms: improved analysis and implementation
# similarity:  1.0000001
#
# paper 1:  Monte Carlo Value Iteration for Continuous-State POMDPs
# paper 2:  Monte Carlo Value Iteration for Continuous-State POMDPs
# similarity:  1.0000001
#
# paper 1:  Monte Carlo Value Iteration for Continuous-State POMDPs
# paper 2:  Solving Continuous POMDPs: Value Iteration with Incremental Learning of an Efficient Space Representation
# similarity:  1.0
#
# paper 1:  Monte Carlo Value Iteration for Continuous-State POMDPs
# paper 2:  Thompson sampling based Monte-Carlo planning in POMDPs
# similarity:  1.0
#
# paper 1:  Monte Carlo Value Iteration for Continuous-State POMDPs
# paper 2:  Bounded Finite State Controllers
# similarity:  1.0
#
# paper 1:  Mood tracking in virtual meetings
# paper 2:  Supporting Collaborative Reflection at Work: A Comparative Case Analysis
# similarity:  1.0000002000000001
#
# paper 1:  Mood tracking in virtual meetings
# paper 2:  Understanding affect in the workplace via social media
# similarity:  1.0000002000000001
#
# paper 1:  Mood tracking in virtual meetings
# paper 2:  Mood tracking in virtual meetings
# similarity:  1.0000002000000001
#
# paper 1:  Mood tracking in virtual meetings
# paper 2:  Emotional awareness in collaborative systems
# similarity:  1.0000002000000001
#
# paper 1:  Mood tracking in virtual meetings
# paper 2:  Lessons Learnt Working with Performance Data in Call Centres
# similarity:  1.0000001
#
# paper 1:  Mood tracking in virtual meetings
# paper 2:  Fostering Collaborative Redesign of Work Practice: Challenges for Tools Supporting Reflection at Work
# similarity:  1.0000001
#
# paper 1:  Mood tracking in virtual meetings
# paper 2:  Honest signals in video conferencing
# similarity:  1.0000001
#
# paper 1:  Mood tracking in virtual meetings
# paper 2:  Amplifying reflective thinking in musical performance
# similarity:  1.0000001
#
# paper 1:  Mood tracking in virtual meetings
# paper 2:  Capturing the mood: facebook and face-to-face encounters in the workplace
# similarity:  1.0000001
#
# paper 1:  Mood tracking in virtual meetings
# paper 2:  Supporting mood awareness in collaborative settings
# similarity:  1.0000001
#
# paper 1:  Adaptation of Robot Behaviour through Online Evolution and Neuromodulated Learning
# paper 2:  Evolution of Embodied Intelligence
# similarity:  1.0000002000000001
#
# paper 1:  Adaptation of Robot Behaviour through Online Evolution and Neuromodulated Learning
# paper 2:  Evolution of homing navigation in a real mobile robot
# similarity:  1.0000002000000001
#
# paper 1:  Adaptation of Robot Behaviour through Online Evolution and Neuromodulated Learning
# paper 2:  Overcoming deception in evolution of cognitive behaviors
# similarity:  1.0000002000000001
#
# paper 1:  Adaptation of Robot Behaviour through Online Evolution and Neuromodulated Learning
# paper 2:  CMA-ES for Hyperparameter Optimization of Deep Neural Networks
# similarity:  1.0000002000000001
#
# paper 1:  Adaptation of Robot Behaviour through Online Evolution and Neuromodulated Learning
# paper 2:  Novelty of behaviour as a basis for the neuro-evolution of operant reward learning
# similarity:  1.0000002000000001
#
# paper 1:  Adaptation of Robot Behaviour through Online Evolution and Neuromodulated Learning
# paper 2:  In search of intelligence: evolving a developmental neuron capable of learning
# similarity:  1.0000002000000001
#
# paper 1:  Adaptation of Robot Behaviour through Online Evolution and Neuromodulated Learning
# paper 2:  Neuro-Centric and Holocentric Approaches to the Evolution of Developmental Neural Networks
# similarity:  1.0000002000000001
#
# paper 1:  Adaptation of Robot Behaviour through Online Evolution and Neuromodulated Learning
# paper 2:  Sequential behavior and learning in evolved dynamical neural networks
# similarity:  1.0000001
#
# paper 1:  Adaptation of Robot Behaviour through Online Evolution and Neuromodulated Learning
# paper 2:  Coevolution of Neuro-developmental Programs That Play Checkers
# similarity:  1.0000001
#
# paper 1:  Adaptation of Robot Behaviour through Online Evolution and Neuromodulated Learning
# paper 2:  How novelty search escapes the deceptive trap of learning to learn
# similarity:  1.0000001
#
# paper 1:  Wireless Sensor Networks in Home Care
# paper 2:  SOMM: A New Service Oriented Middleware for Generic Wireless Multimedia Sensor Networks Based on Code Mobility
# similarity:  1.0000002000000001
#
# paper 1:  Wireless Sensor Networks in Home Care
# paper 2:  Adaptive and Secure Load-Balancing Routing Protocol for Service-Oriented Wireless Sensor Networks
# similarity:  1.0000001
#
# paper 1:  Wireless Sensor Networks in Home Care
# paper 2:  QoS Challenges and Opportunities in Wireless Sensor/Actuator Networks
# similarity:  1.0000001
#
# paper 1:  Wireless Sensor Networks in Home Care
# paper 2:  A partnership-based approach to improve QoS on federated computing infrastructures
# similarity:  1.0000001
#
# paper 1:  Wireless Sensor Networks in Home Care
# paper 2:  Wireless Sensor Networks in Home Care
# similarity:  1.0000001
#
# paper 1:  Wireless Sensor Networks in Home Care
# paper 2:  Middleware for Wireless Sensor Networks: A Survey
# similarity:  1.0000001
#
# paper 1:  Wireless Sensor Networks in Home Care
# paper 2:  Design of SOA Based Framework for Collaborative Cloud Computing in Wireless Sensor Networks
# similarity:  1.0000001
#
# paper 1:  Wireless Sensor Networks in Home Care
# paper 2:  A trust-aware, self-organizing system for large-scale federations of utility computing infrastructures
# similarity:  1.0000001
#
# paper 1:  Wireless Sensor Networks in Home Care
# paper 2:  Uranus: a middleware architecture for dependable AAL and vital signs monitoring applications.
# similarity:  1.0
#
# paper 1:  Wireless Sensor Networks in Home Care
# paper 2:  Integration of Wireless Sensor and Actuator Nodes With IT Infrastructure Using Service-Oriented Architecture
# similarity:  1.0
#
# paper 1:  Is Twitter a Public Sphere for Online Conflicts? A Cross-Ideological and Cross-Hierarchical Look
# paper 2:  Search engine coverage bias: evidence and possible causes
# similarity:  1.0000001
#
# paper 1:  Is Twitter a Public Sphere for Online Conflicts? A Cross-Ideological and Cross-Hierarchical Look
# paper 2:  Events and Controversies: Influences of a Shocking News Event on Information Seeking
# similarity:  1.0000001
#
# paper 1:  Is Twitter a Public Sphere for Online Conflicts? A Cross-Ideological and Cross-Hierarchical Look
# paper 2:  Measuring search engine bias
# similarity:  1.0000001
#
# paper 1:  Is Twitter a Public Sphere for Online Conflicts? A Cross-Ideological and Cross-Hierarchical Look
# paper 2:  Inferring who-is-who in the Twitter social network
# similarity:  1.0000001
#
# paper 1:  Is Twitter a Public Sphere for Online Conflicts? A Cross-Ideological and Cross-Hierarchical Look
# paper 2:  #Snowden: Understanding Biases Introduced by Behavioral Differences of Opinion Groups on Social Media
# similarity:  1.0000001
#
# paper 1:  Is Twitter a Public Sphere for Online Conflicts? A Cross-Ideological and Cross-Hierarchical Look
# paper 2:  Political hashtag trends
# similarity:  1.0000001
#
# paper 1:  Is Twitter a Public Sphere for Online Conflicts? A Cross-Ideological and Cross-Hierarchical Look
# paper 2:  Message Impartiality in Social Media Discussions
# similarity:  1.0
#
# paper 1:  Is Twitter a Public Sphere for Online Conflicts? A Cross-Ideological and Cross-Hierarchical Look
# paper 2:  Is Twitter a Public Sphere for Online Conflicts? A Cross-Ideological and Cross-Hierarchical Look
# similarity:  1.0
#
# paper 1:  Is Twitter a Public Sphere for Online Conflicts? A Cross-Ideological and Cross-Hierarchical Look
# paper 2:  Search result diversity for informational queries
# similarity:  0.99999994
#
# paper 1:  Is Twitter a Public Sphere for Online Conflicts? A Cross-Ideological and Cross-Hierarchical Look
# paper 2:  Measuring personalization of web search
# similarity:  0.76462466
#
# paper 1:  A Framework for Modeling, Computing and Presenting Time-Aware Recommendations
# paper 2:  Mediation of user models for enhanced personalization in recommender systems
# similarity:  1.0000001
#
# paper 1:  A Framework for Modeling, Computing and Presenting Time-Aware Recommendations
# paper 2:  Context Recommendation Using Multi-label Classification
# similarity:  1.0
#
# paper 1:  A Framework for Modeling, Computing and Presenting Time-Aware Recommendations
# paper 2:  Challenges and Solutions of Ubiquitous User Modeling
# similarity:  1.0
#
# paper 1:  A Framework for Modeling, Computing and Presenting Time-Aware Recommendations
# paper 2:  Hybreed: A software framework for developing context-aware hybrid recommender systems
# similarity:  0.9999998999999999
#
# paper 1:  A Framework for Modeling, Computing and Presenting Time-Aware Recommendations
# paper 2:  A Framework for Modeling, Computing and Presenting Time-Aware Recommendations
# similarity:  0.9999998999999999
#
# paper 1:  A Framework for Modeling, Computing and Presenting Time-Aware Recommendations
# paper 2:  Context-Aware Movie Recommendations: An Empirical Comparison of Pre-filtering, Post-filtering and Contextual Modeling Approaches
# similarity:  0.9999998999999999
#
# paper 1:  A Framework for Modeling, Computing and Presenting Time-Aware Recommendations
# paper 2:  ConRec: A Software Framework for Context-Aware Recommendation Based on Dynamic and Personalized Context
# similarity:  0.9999998999999999
#
# paper 1:  A Framework for Modeling, Computing and Presenting Time-Aware Recommendations
# paper 2:  Using Appropriate Context Models for CARS Context Modelling
# similarity:  0.9999998999999999
#
# paper 1:  A Framework for Modeling, Computing and Presenting Time-Aware Recommendations
# paper 2:  CARSKit: A Java-Based Context-Aware Recommendation Engine
# similarity:  0.9999998999999999
#
# paper 1:  A Framework for Modeling, Computing and Presenting Time-Aware Recommendations
# paper 2:  Collaborative user modeling for enhanced content filtering in recommender systems
# similarity:  0.9999998
